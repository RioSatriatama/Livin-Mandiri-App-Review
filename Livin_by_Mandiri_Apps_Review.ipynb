# %% [markdown]
# <a href="https://colab.research.google.com/github/RioSatriatama/Livin-Mandiri-App-Review/blob/main/Livin_by_Mandiri_Apps_Review.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import Library**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %% [markdown]
# # **Import Dataset**

# %%
df = pd.read_csv('/content/reviews.csv')
df
# Out:
#                        date  \
# 0       2021-09-30 06:12:53
# 1       2021-09-30 06:33:15
# 2       2021-09-30 06:48:30
# 3       2021-09-30 06:56:05
# 4       2021-09-30 07:02:21
# ...                     ...
# 155187  2022-12-24 04:04:31
# 155188  2022-12-24 04:05:17
# 155189  2022-12-24 04:13:18
# 155190  2022-12-24 04:17:13
# 155191  2022-12-24 04:17:52
#
#                                                    review  rating  thumbs_up  \
# 0       Udah di coba, keren dan responsive, dengan tam...       5         36
# 1                                               Excellent       5          0
# 2       Keren. Cakep benar semakin canggih. Terdepan t...       5         22
# 3                                                  mantap       5          0
# 4                                                  Mantap       5          0
# ...                                                   ...     ...        ...
# 155187                                      Mantap pokoke       5          0
# ...

# %% [markdown]
# # **Create Ploting / Pie chart**

# %%
fig, ax = plt.subplots(figsize = (5, 5))
colors = sns.color_palette('pastel')

count_rating = [count for count in df['rating'].value_counts()]
labels_rating = list(df['rating'].value_counts().index)

plt.title('Ratings', fontsize = 16)
ax.pie(x=count_rating, labels=labels_rating, autopct = '%1.1f%%',
       textprops={'fontsize': 14}, colors=colors)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
text = " ".join(review for review in df[df.rating <= 5].review)
stopwords = ['nya', 'livin', 'yg', 'ada', 'aja', 'dan', 'saya',
             'ini', 'itu', 'apk', 'mandiri', 'di', 'aplikasi',
             'aplikasinya']
wordcloud = WordCloud(collocations = True, max_font_size = 50,
                      stopwords = stopwords, max_words = 100,
                      background_color = "white").generate(text)
fig, ax = plt.subplots(figsize = (10, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
